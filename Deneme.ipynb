# %%
## İndirme Konumu !!!!! Kendi bilgisayarınıza göre değiştirin !!!!!
download_dir = r"C:\Users\oguzo\Desktop\Selenium\İndirme" 
import pandas as pd

# %%
a = pd.read_excel('Key.xlsx')
# Initialize list
my_list = list(a['GTIP'])
# Chunk size 3
chunk_size = 25
# Split the list 
chunks = [my_list[i:i+chunk_size] for i in range(0, len(my_list), chunk_size)]

# %%
## Required Libraries
import pandas as pd
import selenium
import glob
import os
import shutil
import warnings
import time
warnings.filterwarnings('ignore')
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import UnexpectedAlertPresentException

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options

# Set up options for Firefox
options = Options()
options.binary_location = r"C:\Program Files\Mozilla Firefox\firefox.exe"  # Correct path to firefox.exe
options.set_preference("browser.download.folderList", 2)
options.set_preference("browser.download.manager.showWhenStarting", False)
options.set_preference("browser.download.dir", r"C:\path\to\download_dir")  # Correct your download directory path
options.set_preference("browser.helperApps.neverAsk.saveToDisk", "application/vnd.ms-excel")

# Set up the service for geckodriver
service = Service(executable_path=r"C:\Users\oguzo\Desktop\Selenium\geckodriver.exe")

# Initialize the WebDriver
browser = webdriver.Firefox(service=service, options=options)

# Open the website
browser.get('https://biruni.tuik.gov.tr/disticaretapp/menu.zul')

# %%
y = 1
for ykey in chunks:
    text = ''
    for xx in range(0,len(ykey)):
        if xx < len(ykey) -1:
            text = text + str(ykey[xx]) + ','
        else:
            text = text + str(ykey[xx])
    
    for year in reversed(range(2020,2025)):
        ## Required Libraries
        import pandas as pd
        import selenium
        import glob
        import os
        import shutil
        import warnings
        import time
        warnings.filterwarnings('ignore')

        from selenium import webdriver
        from selenium.webdriver.firefox.options import Options
        from selenium.webdriver.firefox.service import Service
        from selenium.webdriver.common.by import By
        from selenium.webdriver.support import expected_conditions as EC
        from selenium.webdriver.support.ui import WebDriverWait

        ## Required Code due to errors occured
        from selenium.common.exceptions import UnexpectedAlertPresentException

        # Set up options for Firefox
        options = Options()
        options.binary_location = r"C:\Program Files\Mozilla Firefox\firefox.exe"  # Correct path to firefox.exe
        options.set_preference("browser.download.folderList", 2)
        options.set_preference("browser.download.manager.showWhenStarting", False)
        options.set_preference("browser.download.dir", download_dir)  # Correct your download directory path
        options.set_preference("browser.helperApps.neverAsk.saveToDisk", "application/vnd.ms-excel")

        # Set up the service for geckodriver
        service = Service(executable_path=r"C:\Users\oguzo\Desktop\Selenium\geckodriver.exe")

        # Initialize the WebDriver
        browser = webdriver.Firefox(service=service, options=options)

        # Open the website
        browser.get('https://biruni.tuik.gov.tr/disticaretapp/menu.zul')

        ### Ürün Ürün grubu Ülke
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div/table/tbody[1]/tr[1]/td/div/table/tbody/tr/td/table/tbody/tr/td[1]/div/div[3]/table/tbody[2]/tr[2]/td/div"))).click()
        ## Radio
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div/table/tbody[1]/tr[13]/td/div/span/span[1]/label"))).click()
        ## HS
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div/table/tbody[1]/tr[14]/td/div/table/tbody/tr/td/table/tbody/tr[3]/td/span/span[1]/label"))).click()
        ## HS6
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div/table/tbody[1]/tr[15]/td/div/span/span[5]/input"))).click()
        ## İleri
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div/table/tbody[1]/tr[17]/td/div/table/tbody/tr/td/table/tbody/tr/td[1]/button"))).click()
        ## Kümülatif
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[5]/td/div/div/table/tbody[1]/tr/td/div/table/tbody/tr/td/table/tbody/tr/td[1]/table/tbody/tr/td/table/tbody/tr/td/span/span[2]/input"))).click()


        ## Yıl
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[5]/td/div/div/table/tbody[1]/tr/td/div/table/tbody/tr/td/table/tbody/tr/td[5]/div/div[3]/table/tbody[2]/tr[{2025-year}]/td/div"))).click()
        ## Tüm Aylar
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[5]/td/div/div/table/tbody[1]/tr/td/div/table/tbody/tr/td/table/tbody/tr/td[9]/div/div[3]/table/tbody[2]/tr[1]/td/div"))).click()
        ## HS12 kodu
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[7]/td/div/div/table/tbody[1]/tr[2]/td/div/table/tbody/tr/td/table/tbody/tr[11]/td/span/span[2]/input"))).click()
        ## İhraca
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[11]/td/div/div/table/tbody[1]/tr[1]/td/div/table/tbody/tr/td/table/tbody/tr/td[3]/span/input"))).click()
        ## İthalat
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[11]/td/div/div/table/tbody[1]/tr[1]/td/div/table/tbody/tr/td/table/tbody/tr/td[5]/span/input"))).click()
        ## Dolar
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[11]/td/div/div/table/tbody[1]/tr[2]/td/div/table/tbody/tr/td/table/tbody/tr/td[3]/span/input"))).click()
        ## Excel
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[13]/td/div/div/table/tbody[1]/tr/td[1]/div/table/tbody/tr/td/table/tbody/tr/td[3]/span/span[2]/input"))).click()
        ### Kodlar
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[7]/td/div/div/table/tbody[1]/tr[3]/td/div/input"))).send_keys(text)
        ### İndir
        WebDriverWait(browser, 20).until(EC.element_to_be_clickable((By.XPATH, f"/html/body/div/div/div[2]/div/div/div/table/tbody/tr/td/table/tbody/tr[17]/td/div/div[3]/table/tbody[2]/tr/td[2]/div/button"))).click()
        time.sleep(10)
        # Quit the driver
        browser.quit()

        ## Dosya'nın adının değiştirilmesi

        ## En son indirilen dosyayı bul
        list_of_files = glob.glob(f'{download_dir}/*') 
        latest_file = max(list_of_files, key=os.path.getctime)

        a = latest_file.split('/')
        key_file = ''
        for zz in range(0,len(a)-1):
                key_file = key_file + a[zz] + '/'

        os.rename(latest_file, key_file + f'{y}.xls')

        y += 1

# %%
latest_file
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 latest_file
#
# NameError: name 'latest_file' is not defined

# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

#Define coordinates of where we want to center our map
boulder_coords = [40.015, -105.2705]

#Create the map
my_map = folium.Map(location = boulder_coords, zoom_start = 13)


#Define the coordinates we want our markers to be at
CU_Boulder_coords = [40.007153, -105.266930]
East_Campus_coords = [40.013501, -105.251889]
SEEC_coords = [40.009837, -105.241905]

#Add markers to the map
folium.Marker(CU_Boulder_coords, popup = 'CU Boulder').add_to(my_map)
folium.Marker(East_Campus_coords, popup = 'East Campus').add_to(my_map)
folium.Marker(SEEC_coords, popup = 'SEEC Building').add_to(my_map)

#Display the map
my_map
